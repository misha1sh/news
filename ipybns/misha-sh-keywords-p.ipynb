# %%
import importer
data_from_parser = importer.load()
# Out:
# cfo 1267
# cons 100
# klerk 4506
# rbc 931

# %%
from digester import get_digest
res = get_digest(data_from_parser, person_type="all_without_rbc", days=90, count=3, debug=True)
# Out:
# cluster:  8  count= 66
# Россияне рекордно задолжали за ЖКУ. Людям приходится выбирать между продуктами и коммуналкой https://www.klerk.ru/buh/news/532989/
# Хорошая зарплата, новый начальник и отказ от вакцинации. Россияне рассказали, что их удержит от увольнения https://www.klerk.ru/buh/news/532863/
# 🚩 Поменялись формы СЗВ-ТД и СЗВ-СТАЖ https://www.klerk.ru/buh/news/533066/
# {'КСОЮ': 4980.421308740171,
#  'увольнение': 2562.6208714681097,
#  'СЗВ-СТАЖ': 1986.401543209392,
#  'инстанция': 1863.8351551724527,
#  'прогула': 1460.2574938385624,
#  'ПФР': 1442.7360140329968,
#  'незаконно': 1383.1067213888593,
#  'апелляция': 1281.610836267611,
#  'кассация': 1188.8417596543159,
#  'СЗВ-ТД': 1087.4570126151657}
# [{'word': 'года', 'short': 'год', 'count': 0.6515151515151515},
#  {'word': 'работником', 'short': 'работник', 'count': 0.6060606060606061},
#  {'word': 'форму', 'short': 'форм', 'count': 0.5909090909090909},
#  {'word': 'работодателей',
#   'short': 'работодател',
# ...

# %%
# res

# %%
from trender import get_trends

get_trends(data_from_parser, 30)
# Out:
# ['мобилизация',
#  'военкомат',
#  'повестка',
#  'портал',
#  'призыв',
#  'отсрочка',
#  'договор',
#  'служба',
#  'гражданин',
#  'известие',
#  'новость',
#  'форма',
#  'объясняем.рф',
#  'гражданин',
#  'минобороны',
#  'подача',
#  'образование',
#  'турция',
#  'сведение',
#  'стаж']

# %%
def calc_trends2(data_from_parser, use_titles=False):
    from tokenizer import snowball
    from digester import get_digest_words
    import pymorphy2

    morph = pymorphy2.MorphAnalyzer()
    digest_words = get_digest_words(data_from_parser, person_type="all", days=180, count=3, debug=False, use_titles=use_titles)

    res = []
    articles_res = []
    for words in digest_words:
        rres = []
        articles_rres = []
        for word in words:
            normal = morph.parse(word[0])
            normal = normal[0]
            if normal.tag._POS in ["NUMB", "UNKN"]:
                continue
            if normal.tag.POS in ["COMP", "PRTS", "PRTF"]:
                continue
            if normal.normal_form in ["октябрь", "сентябрь", 'август', 'ноябрь', 'июнь', 'вебинар']:
                continue

            form = word[0]
            if word[0].upper() == word[0]:
                form = word[0]
            elif normal.score > 0.7:
                form = normal.normal_form

            short = snowball.stem(word[0])
            articles_rrres = []
            for i in word[2]:
                if short in i['title'] or word[0] in i['title'] or form in i['title']:
                    articles_rrres.append(i['title'])
                    # print(word[0], i['title'])

            articles_rres.append(articles_rrres)
            rres.append(form)
            if len(rres) == 3:
                break
        articles_res.append(articles_rres)

        res.append(rres)
    return res, articles_res

calc_trends2(data_from_parser, use_titles=True)
# Out:
# ([['год', 'сотрудник', 'компания'],
#   ['документооборот', 'документ', 'участие'],
#   ['ФСБУ', 'учёт', 'аренда']],
#  [[['Со следующего года планируют увеличить МРОТ на 963 руб.',
#     'С отчета за 2022 год декларацию по налогу на имущество сдают по обновленной форме',
#     'Для аккредитации старых IT-компаний долю дохода 30% считают за прошлый год, для новых компаний – за текущий',
#     'В 2023 году взносы на производственный травматизм не изменятся: от 0,2% до 8,5%',
#     'За 2022 год надо сдавать декларацию по налогу на имущество новой формы',
#     '❗ Стала известна единая предельная база по взносам в 2023 году',
#     'Бухгалтеры в аутсорсе задумались над повышением цен из-за нововведений с 2023 года',
#     '🔥 С 2023 года справку 182н отменят. Считать больничные будут по данным ФНС',
#     'Параллельный импорт в России продлится на 2023 год',
#     'Бизнес просит Минпромторг продлить параллельный импорт на 2023 год',
# ...

# %%
from digester import get_digest_words
import pymorphy2

digest_words = get_digest_words(data_from_parser, person_type="all", days=180, count=3, debug=False)
morph = pymorphy2.MorphAnalyzer()

res = []
for words in digest_words:
    rres = []
    for word in words:
        normal = morph.parse(word[0])
        normal = normal[0]
        if normal.tag._POS in ["NUMB", "UNKN"]:
            continue
        if normal.tag.POS in ["COMP", "PRTS", "PRTF"]:
            continue
        if normal.normal_form in ["октябрь", "сентябрь", 'август', 'ноябрь', 'июнь', 'вебинар']:
            continue
        
        form = word[0]
        if word[0].upper() == word[0]:
            form = word[0]
        elif normal.score > 0.7:
            form = normal.normal_form
            
        rres.append(form)
        if len(rres) == 3:
            break
            
    res.append(rres)
res
# res = []
# for words in digest_words:
#     res.append(words[0][0],
# Out:
# [['год', 'сотрудник', 'компания'],
#  ['документооборот', 'документ', 'участие'],
#  ['ФСБУ', 'учёт', 'аренда']]

# %%
from digester import get_digest
get_digest(data_from_parser, person_type="all", days=180, count=3, debug=True)
# Out:
# cluster:  19  count= 133
# Zenden возмущен произволом налоговиков, которые доначислили 867 млн руб. по сделкам с подконтрольными ИП https://www.klerk.ru/buh/news/532823/
# Больше радиоэлектронных компаний получат льготы по взносам https://www.klerk.ru/buh/news/529926/
# IT-компании с госучастием 50% не смогут получить аккредитацию https://www.klerk.ru/buh/news/536630/
# {'аккредитац': 13699.50613339248,
#  'IT-компан': 11499.877854458016,
#  'аккредитова': 10659.423292663041,
#  'увольнен': 7305.390272050614,
#  'отсрочк': 5339.760751164662,
#  'ксо': 5024.005061155268,
#  'минцифр': 4876.569726380971,
#  'пфр': 4640.151418420074,
#  'омс': 3604.8818823187707,
#  'дет': 3438.5987565859336}
# cluster:  14  count= 47
# Финансисты и рыболовы получают до 200 тысяч рублей. Правда, в основном в Москве, Мурманске и Магадане https://www.klerk.ru/buh/news/530888/
# Лизингополучатель должен отразить в учете ППА https://www.klerk.ru/buh/news/535474/
# ...

# %%
import time
import datetime

from keyworder import idf_precalc, tf_idf, keywords_sum, keywords_norm, keywords_mean, most_popular_keywords, keywords_diff
from tokenizer import keywords_groups_calc
from clusterizer import clusterize
days=60


def filt(normal):
    if normal.tag._POS in ["NUMB", "UNKN"] or normal.tag.POS in ["COMP", "PRTS", "PRTF"]:
        return True
    if normal.normal_form in ["октябрь", "сентябрь", 'август']:
        return True
    return False
data = data_from_parser["rbc"] + data_from_parser["cfo"] + data_from_parser["cons"] + data_from_parser["klerk"] 

idfs = idf_precalc([ keywords_groups_calc(data, filt=filt) ])

time_begin = time.time() - datetime.timedelta(days=days).total_seconds()
data_before = list(filter(lambda i: time_begin <= i["timestamp"], data))
data_after = list(filter(lambda i: time_begin > i["timestamp"], data))


keyword_groups_before = keywords_groups_calc(data_before, filt=filt)
keyword_groups_after = keywords_groups_calc(data_after, filt=filt)

keyword_groups_before = tf_idf(keyword_groups_before, idfs)
keyword_groups_after = tf_idf(keyword_groups_after, idfs)

# %%
import datetime
import pymorphy2

def fitler_documents_with_word(keyword_groups, word):
    res = []
    for document in keyword_groups:
        if word in document and document[word]['count'] > 2: continue
        res.append(document)
    return res

morph = pymorphy2.MorphAnalyzer()

res = []
for i in range(20):
    keywords = most_popular_keywords(keywords_diff(keywords_mean(keyword_groups_before),
                                    keywords_mean(keyword_groups_after)), 1)
    word = keywords[0]
    normal = morph.parse(word['word'])
    normal = normal[0]
    res.append(normal.normal_form)
    
    keyword_groups_before = fitler_documents_with_word(keyword_groups_before, word['short'])
    keyword_groups_after = fitler_documents_with_word(keyword_groups_after, word['short'])
    
    
    print(word)
    

res
# Out:
# {'word': 'мобилизации', 'short': 'мобилизац', 'count': 0.3896796067763219}
# {'word': 'портале', 'short': 'портал', 'count': 0.17039031231202406}
# {'word': 'Кстати', 'short': 'кстат', 'count': 0.15142352925732042}
# {'word': 'Известиям', 'short': 'извест', 'count': 0.14665431158026448}
# {'word': 'вебинары', 'short': 'вебинар', 'count': 0.13150465479273515}
# {'word': 'портал', 'short': 'порта', 'count': 0.12217296947472842}
# {'word': 'договор', 'short': 'договор', 'count': 0.11169692706761569}
# {'word': 'бюджетом', 'short': 'бюджет', 'count': 0.11724828311446964}
# {'word': 'новостей', 'short': 'новост', 'count': 0.1089346471192893}
# {'word': 'постановление', 'short': 'постановлен', 'count': 0.11026445044276204}
# {'word': 'ФНС', 'short': 'фнс', 'count': 0.09789642530171572}
# {'word': 'июлем', 'short': 'июл', 'count': 0.1122596435449448}
# {'word': 'фотографии', 'short': 'фотограф', 'count': 0.10511580326189653}
# ...

# %%
import time
import datetime

from keyworder import idf_precalc, tf_idf, keywords_sum, keywords_norm, keywords_mean, most_popular_keywords, keywords_diff
from tokenizer import keywords_groups_calc
from clusterizer import clusterize
days=60


def filt(normal):
    if normal.tag._POS in ["NUMB", "UNKN"] or normal.tag.POS in ["COMP", "PRTS", "PRTF"]:
        return True
    if normal.normal_form in ["октябрь", "сентябрь", 'август']:
        return True
    return False
data = data_from_parser["rbc"] + data_from_parser["cfo"] + data_from_parser["cons"] + data_from_parser["klerk"] 

idfs = idf_precalc([ keywords_groups_calc(data, filt=filt, typ='title') ])

time_begin = time.time() - datetime.timedelta(days=days).total_seconds()
data_before = list(filter(lambda i: time_begin <= i["timestamp"], data))
data_after = list(filter(lambda i: time_begin > i["timestamp"], data))


keyword_groups_before = keywords_groups_calc(data_before, filt=filt, typ='title')
keyword_groups_after = keywords_groups_calc(data_after, filt=filt, typ='title')

keyword_groups_before = tf_idf(keyword_groups_before, idfs)
keyword_groups_after = tf_idf(keyword_groups_after, idfs)

import datetime
import pymorphy2

def fitler_documents_with_word(keyword_groups, word):
    res = []
    for document in keyword_groups:
        if word in document and document[word]['count'] > 2: continue
        res.append(document)
    return res

morph = pymorphy2.MorphAnalyzer()

res = []
for i in range(20):
    keywords = most_popular_keywords(keywords_diff(keywords_mean(keyword_groups_before),
                                    keywords_mean(keyword_groups_after)), 20)
    if i == 0:
        display(keywords)
    
    word = keywords[0]
    normal = morph.parse(word['word'])
    normal = normal[0]
    res.append(normal.normal_form)
    
    keyword_groups_before = fitler_documents_with_word(keyword_groups_before, word['short'])
    keyword_groups_after = fitler_documents_with_word(keyword_groups_after, word['short'])
    
    
    print(word)
    
print()
res
# Out:
# [{'word': 'мобилизация', 'short': 'мобилизац', 'count': 0.19495331092755694},
#  {'word': 'сотрудников', 'short': 'сотрудник', 'count': 0.10942102323887776},
#  {'word': 'людей', 'short': 'люд', 'count': 0.10358997474296427},
#  {'word': 'года', 'short': 'год', 'count': 0.09385210694586235},
#  {'word': 'суд', 'short': 'суд', 'count': 0.08394890361944446},
#  {'word': 'форме', 'short': 'форм', 'count': 0.08390984666545771},
#  {'word': 'организация', 'short': 'организац', 'count': 0.07529056470642481},
#  {'word': 'работодателям',
#   'short': 'работодател',
#   'count': 0.07029044416484735},
#  {'word': 'отсрочке', 'short': 'отсрочк', 'count': 0.06826246422121478},
#  {'word': 'деньги', 'short': 'деньг', 'count': 0.06777191584205428},
#  {'word': 'доходов', 'short': 'доход', 'count': 0.06465607708686874},
#  {'word': 'Турцией', 'short': 'турц', 'count': 0.0639273601352845},
#  {'word': 'правил', 'short': 'прав', 'count': 0.06331504545329543},
# ...

# %%
import pymorphy2
import string

morph = pymorphy2.MorphAnalyzer()

normal = morph.parse("руб.")
normal = normal[0]

normal
# Out:
# Parse(word='руб.', tag=OpencorporaTag('UNKN'), normal_form='руб.', score=1.0, methods_stack=((UnknAnalyzer(), 'руб.'),))

# %%
normal.tag._POS
# Out:
# 'UNKN'

# %%
res
# Out:
# [{'url': 'https://www.klerk.ru/buh/news/536857/',
#   'site': 'klerk',
#   'title': 'Кредитные каникулы может оформить не только мобилизованный, но и братья, сестры, родители и дети',
#   'text': '\n\r На брифинге Минтруда сообщили, что право на кредитные каникулы имеют не только мобилизованные граждане, но и члены его семьи, указано на официальном сайте Правительства.\r  К членам семьи мобилизованного относятся супруги, дети, лица на иждивении (родители, братья и сестры).\r Иждивение придется доказать документально.\r На все кредиты, которые были получены мобилизованным или членом его семьи до 21 сентября, можно оформить кредитные каникулы.\r Кредитные каникулы предоставляются на весь срок мобилизации и плюс 30 дней после возвращения.\n\n\n',
#   'description': 'Закон о кредитных каникулах позволяет оформить их не только мобилизованному гражданину, но членам его семьи.',
#   'timestamp': 1664984640.0},
#  {'url': 'https://www.klerk.ru/buh/news/536968/',
#   'site': 'klerk',
# ...

# %%
most_popular_keywords(keywords_diff(keyword_groups_before[1], 
                                    keywords_mean(keyword_groups_before[2:])), 20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 most_popular_keywords(keywords_diff(keyword_groups_before[1],
#       2                                     keywords_mean(keyword_groups_before[2:])), 20)
#
# NameError: name 'keyword_groups_before' is not defined

# %%
    
keyword_groups_before = keywords_groups_calc(data_before)
keyword_groups_after = keywords_groups_calc(data_after)

idfs = idf_precalc([keyword_groups_before, keyword_groups_after])

keyword_groups_before = tf_idf(keyword_groups_before, idfs)
keyword_groups_after = tf_idf(keyword_groups_after, idfs)

most_popular_keywords(keywords_diff(keywords_mean(keyword_groups_before), 
                                    keywords_mean(keyword_groups_after)), 20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [4], line 8
#       5     keywords_groups = Parallel(n_jobs=16)(delayed(keywords_calc)(i['text']) for i in data)
#       6     return keywords_groups
# ----> 8 keyword_groups_before = keywords_groups_calc(data_before)
#       9 keyword_groups_after = keywords_groups_calc(data_after)
#      11 idfs = idf_precalc([keyword_groups_before, keyword_groups_after])
#
# NameError: name 'data_before' is not defined

# %%
keyword_groups_before = keywords_groups_calc(data_before)
keyword_groups_after = keywords_groups_calc(data_after)

# keywords = keywords_sum(keyword_groups)
# most_popular_keywords(keywords, 5)

# most_popular_keywords(keywords_diff(keyword_groups[0], keywords_mean(keyword_groups[1:])), 5)
# most_popular_keywords(keywords_diff(keyword_groups[0], keywords_mean(keyword_groups[60:])), 5)

most_popular_keywords(keywords_diff(keywords_mean(keywords_norm(keyword_groups_before)), 
                                    keywords_mean(keywords_norm(keyword_groups_after))), 20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 keyword_groups_before = keywords_groups_calc(data_before)
#       2 keyword_groups_after = keywords_groups_calc(data_after)
#       4 # keywords = keywords_sum(keyword_groups)
#       5 # most_popular_keywords(keywords, 5)
#       6
#       7 # most_popular_keywords(keywords_diff(keyword_groups[0], keywords_mean(keyword_groups[1:])), 5)
#       8 # most_popular_keywords(keywords_diff(keyword_groups[0], keywords_mean(keyword_groups[60:])), 5)
#
# NameError: name 'data_before' is not defined

# %%
keyword_groups_before = keywords_groups_calc(data_before)
keyword_groups_after = keywords_groups_calc(data_after)

most_popular_keywords(keywords_diff(keywords_mean(keyword_groups_before), 
                                    keywords_mean(keyword_groups_after)), 20)
# Out:
# [{'word': 'мобилизации', 'short': 'мобилизац', 'count': 0.24858733530481625},
#  {'word': 'мобилизованные',
#   'short': 'мобилизова',
#   'count': 0.2124897607841504},
#  {'word': 'Сотрудники', 'short': 'сотрудник', 'count': 0.12521693253918667},
#  {'word': 'службе', 'short': 'служб', 'count': 0.1125966651394616},
#  {'word': 'отсрочку', 'short': 'отсрочк', 'count': 0.10762630680161606},
#  {'word': 'Минцифры', 'short': 'минцифр', 'count': 0.10662668166104378},
#  {'word': 'повестку', 'short': 'повестк', 'count': 0.10430810668221639},
#  {'word': 'РФ', 'short': 'рф', 'count': 0.07951184972302053},
#  {'word': 'семей', 'short': 'сем', 'count': 0.07694336845905009},
#  {'word': 'заявление', 'short': 'заявлен', 'count': 0.07133436072583892},
#  {'word': 'лет', 'short': 'лет', 'count': 0.0674885806711372},
#  {'word': 'военкомат', 'short': 'военкомат', 'count': 0.06644730448304108},
#  {'word': 'учета', 'short': 'учет', 'count': 0.058297582850875364},
# ...

# %%
from cfo_parser import get_cfo_days
from parsers.kelrk_parser import parse_klerk_news

# data = get_cfo_days(30)
data = parse_klerk_news(30)
len(data)
for i in data:
    i["timestap"] /= 1000
# Out:
# 930

# %%
# Out:
# cfo 1280
# cons 100
# klerk 4504

# %%
import time
import datetime

data = data_cfo + data_cons + data_klerk
idfs = idf_precalc([ keywords_groups_calc(data) ])

time_begin = time.time() - datetime.timedelta(days=1).total_seconds()
data_before = list(filter(lambda i: time_begin <= i["timestamp"], data))
data_after = list(filter(lambda i: time_begin > i["timestamp"], data))

len(data_before), len(data_after)
# Out:
# (23, 5861)

# %%
# Out:
# 113

# %%
from tqdm.notebook import tqdm
import math
def dist(d1, d2):
    s = 0
    for w in d1["short"] & d2["short"]:
        # s += 1.
        # s += math.log2(d1["long"][w]["count"] * d2["long"][w]["count"] + 10)
        s += d1["long"][w]["count"] * d2["long"][w]["count"]
    return max(500 - s, 0)
        # return math.log2(max(300 - s, 0) + 1)



distances = []
for i in tqdm(range(len(popular_keywords))):
    document = popular_keywords[i]
    d = []
    for j in range(len(popular_keywords)):
        if i == j:
            d.append(0)
        elif i > j:
            d.append(distances[j][i])
        else:
            document2 = popular_keywords[j]
            d.append(dist(document, document2))
    distances.append(d)
    
# from sklearn.cluster import DBSCAN
# import numpy as np
# distances = np.array(distances)
# clustering = DBSCAN(eps=3, min_samples=2, metric='precomputed').fit(distances)
# labels = clustering.labels_
import collections
import hdbscan
import numpy as np
clusterer = hdbscan.HDBSCAN(metric='precomputed')
distances = np.array(distances)
clustering = clusterer.fit(distances)

def clustering_score(labels):
    score = 0
    counter = collections.Counter(labels)
    for label, count in counter.most_common(100):
        if label == -1: continue
        if count > 10 and count < 30:
            score += 2
        score += 1
    return score
    
clustering_scores = []
for i in range(0, 500):
    labels = clustering.single_linkage_tree_.get_clusters(i, min_cluster_size=3)
    score = clustering_score(labels)
    clustering_scores.append(score)
    
i = np.argmax(clustering_scores)
print("oprimal_clustering", i)
labels = clustering.single_linkage_tree_.get_clusters(i, min_cluster_size=3)
    
counter = collections.Counter(labels)
counter
# Out:
#   0%|          | 0/113 [00:00<?, ?it/s]
# oprimal_clustering 408
# Counter({-1: 102, 0: 11})

# %%
def dist_most_common(d):
    s = 0
    from collections import defaultdict
    words = defaultdict(lambda:0)
    for i in range(len(d)):
        for j in range(i + 1, len(d)):
            d1 = d[i]
            d2 = d[j]
            for w in d1["short"] & d2["short"]:
                words[w] += d1["long"][w]["count"] * d2["long"][w]["count"]
                
    words = list(words.items())
    words.sort(key=lambda w: -w[1])
    return words[:10]

for label, count in counter.most_common(8):
    if label == -1:
        continue
    print("cluster: ", label, " count=", count)
    ddocs = []
    ddocs_i = []
    dpopular_keywords = []
    for i in range(len(keyword_groups)):
        if labels[i] == label:
            ddocs.append(keyword_groups[i])
            ddocs_i.append(i)
            dpopular_keywords.append(popular_keywords[i])
            
    distances_i = []
    for i in ddocs_i:
        d = 0
        for j in ddocs_i:
            d += distances[i][j]
        distances_i.append((d, i))
    distances_i.sort(key=lambda i: i[0])     
    for score, i in distances_i[:3]:
        art = data_news[i]
        print(art["title"], art["url"])
    
    display(dict(dist_most_common(dpopular_keywords)))
    display(most_popular_keywords(keywords_mean(ddocs), 10))
    
    print()
    print()
# Out:
# cluster:  0  count= 11
# Кредитные каникулы может оформить не только мобилизованный, но и братья, сестры, родители и дети https://www.klerk.ru/buh/news/536857/
# ✅ Заработали поправки в Трудовой кодекс для мобилизованных https://www.klerk.ru/buh/news/537107/
# Если вы утратили трудоспособность, у вас болеют родственники или в регионе стихийное бедствие, вы можете не явиться в военкомат https://www.klerk.ru/buh/news/536964/
# {'мобилизова': 367.36004214423394,
#  'повестк': 304.76824754208445,
#  'член': 297.12765226534765,
#  'сем': 277.92648351600036,
#  'граждан': 268.5085247615393,
#  'окончан': 202.4077508741768,
#  'коп': 140.76234962447765,
#  'служб': 137.7057913908593,
#  'родител': 136.60058609264664,
#  'обстоятельств': 134.1175016015779}
# [{'word': 'мобилизованные', 'short': 'мобилизова', 'count': 2.847576310999853},
#  {'word': 'повестки', 'short': 'повестк', 'count': 2.591651132620666},
#  {'word': 'окончания', 'short': 'окончан', 'count': 2.5507280790122837},
# ...

# %%
import matplotlib.pyplot as plt
plt.matshow(distances)
